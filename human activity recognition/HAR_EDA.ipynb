# %% [markdown]
# # HumanActivityRecognition
#
# <br>
#
#
# This project is to build a model that predicts the human activities such as Walking, Walking_Upstairs, Walking_Downstairs, Sitting, Standing or Laying.
#
# This dataset is collected from 30 persons(referred as subjects in this dataset), performing different activities with a smartphone to their waists. The data is recorded with the help of sensors (accelerometer and Gyroscope) in that smartphone. This experiment was video recorded to label the data manually.
#
# ## How data was recorded
#
# By using the sensors(Gyroscope and accelerometer) in a smartphone, they have captured '3-axial linear acceleration'(_tAcc-XYZ_) from accelerometer and '3-axial angular velocity' (_tGyro-XYZ_) from Gyroscope with several variations.
#
# > prefix 't' in those metrics denotes time.
#
# > suffix 'XYZ' represents 3-axial signals in X , Y, and Z directions.
#
# ### Feature names
#
# 1. These sensor signals are preprocessed by applying noise filters and then sampled in fixed-width windows(sliding windows) of 2.56 seconds each with 50% overlap. ie., each window has 128 readings.
#
# 2. From Each window, a feature vector was obtianed by calculating variables from the time and frequency domain.
# > In our dataset, each datapoint represents a window with different readings
# 3. The accelertion signal was saperated into Body and Gravity acceleration signals(___tBodyAcc-XYZ___ and ___tGravityAcc-XYZ___) using some low pass filter with corner frequecy of 0.3Hz.
#
# 4. After that, the body linear acceleration and angular velocity were derived in time to obtian _jerk signals_ (___tBodyAccJerk-XYZ___ and ___tBodyGyroJerk-XYZ___).
#
# 5. The magnitude of these 3-dimensional signals were calculated using the Euclidian norm. This magnitudes are represented as features with names like _tBodyAccMag_, _tGravityAccMag_, _tBodyAccJerkMag_, _tBodyGyroMag_ and _tBodyGyroJerkMag_.
#
# 6. Finally, We've got frequency domain signals from some of the available signals by applying a FFT (Fast Fourier Transform). These signals obtained were labeled with ___prefix 'f'___ just like original signals with ___prefix 't'___. These signals are labeled as ___fBodyAcc-XYZ___, ___fBodyGyroMag___ etc.,.
#
# 7. These are the signals that we got so far.
# 	+ tBodyAcc-XYZ
# 	+ tGravityAcc-XYZ
# 	+ tBodyAccJerk-XYZ
# 	+ tBodyGyro-XYZ
# 	+ tBodyGyroJerk-XYZ
# 	+ tBodyAccMag
# 	+ tGravityAccMag
# 	+ tBodyAccJerkMag
# 	+ tBodyGyroMag
# 	+ tBodyGyroJerkMag
# 	+ fBodyAcc-XYZ
# 	+ fBodyAccJerk-XYZ
# 	+ fBodyGyro-XYZ
# 	+ fBodyAccMag
# 	+ fBodyAccJerkMag
# 	+ fBodyGyroMag
# 	+ fBodyGyroJerkMag
#
# 8. We can esitmate some set of variables from the above signals. ie., We will estimate the following properties on each and every signal that we recoreded so far.
#
# 	+ ___mean()___: Mean value
# 	+ ___std()___: Standard deviation
# 	+ ___mad()___: Median absolute deviation
# 	+ ___max()___: Largest value in array
# 	+ ___min()___: Smallest value in array
# 	+ ___sma()___: Signal magnitude area
# 	+ ___energy()___: Energy measure. Sum of the squares divided by the number of values.
# 	+ ___iqr()___: Interquartile range
# 	+ ___entropy()___: Signal entropy
# 	+ ___arCoeff()___: Autorregresion coefficients with Burg order equal to 4
# 	+ ___correlation()___: correlation coefficient between two signals
# 	+ ___maxInds()___: index of the frequency component with largest magnitude
# 	+ ___meanFreq()___: Weighted average of the frequency components to obtain a mean frequency
# 	+ ___skewness()___: skewness of the frequency domain signal
# 	+ ___kurtosis()___: kurtosis of the frequency domain signal
# 	+ ___bandsEnergy()___: Energy of a frequency interval within the 64 bins of the FFT of each window.
# 	+ ___angle()___: Angle between to vectors.
#
# 9. We can obtain some other vectors by taking the average of signals in a single window sample. These are used on the angle() variable'
# `
# 	+ gravityMean
# 	+ tBodyAccMean
# 	+ tBodyAccJerkMean
# 	+ tBodyGyroMean
# 	+ tBodyGyroJerkMean
#
#
# ###  Y_Labels(Encoded)
# + In the dataset, Y_labels are represented as numbers from 1 to 6 as their identifiers.
#
# 	- WALKING as __1__
# 	- WALKING_UPSTAIRS as __2__
# 	- WALKING_DOWNSTAIRS as __3__
# 	- SITTING as __4__
# 	- STANDING as __5__
# 	- LAYING as __6__
#
# ## Train and test data were saperated
#  - The readings from ___70%___ of the volunteers were taken as ___trianing data___ and remaining ___30%___ subjects recordings were taken for ___test data___
#
# ## Data
#
# * All the data is present in 'UCI_HAR_dataset/' folder in present working directory.
#      - Feature names are present in 'UCI_HAR_dataset/features.txt'
#      - ___Train Data___
#          - 'UCI_HAR_dataset/train/X_train.txt'
#          - 'UCI_HAR_dataset/train/subject_train.txt'
#          - 'UCI_HAR_dataset/train/y_train.txt'
#      - ___Test Data___
#          - 'UCI_HAR_dataset/test/X_test.txt'
#          - 'UCI_HAR_dataset/test/subject_test.txt'
#          - 'UCI_HAR_dataset/test/y_test.txt'
#
#
# ## Data Size :
# > 27 MB

# %% [markdown]
# # Quick overview of the dataset :

# %% [markdown]
# * Accelerometer and Gyroscope readings are taken from 30 volunteers(referred as subjects) while performing the following 6 Activities.
#
#     1. Walking
#     2. WalkingUpstairs
#     3. WalkingDownstairs
#     4. Standing
#     5. Sitting
#     6. Lying.
#
#
# * Readings are divided into a window of 2.56 seconds with 50% overlapping.
#
# * Accelerometer readings are divided into gravity acceleration and body acceleration readings,
#   which has x,y and z components each.
#
# * Gyroscope readings are the measure of angular velocities which has x,y and z components.
#
# * Jerk signals are calculated for BodyAcceleration readings.
#
# * Fourier Transforms are made on the above time readings to obtain frequency readings.
#
# * Now, on all the base signal readings., mean, max, mad, sma, arcoefficient, engerybands,entropy etc., are calculated for each window.
#
# * We get a feature vector of 561 features and these features are given in the dataset.
#
# * Each window of readings is a datapoint of 561 features.
#
# ## Problem Framework
#
# * 30 subjects(volunteers) data is randomly split to 70%(21) test and 30%(7) train data.
# * Each datapoint corresponds one of the 6 Activities.

# %% [markdown]
# ## Problem Statement
#
#  + Given a new datapoint we have to predict the Activity

# %%
#given dataset data was not correct showing duplicates, so replaced duplicates with name like "faBodyGyro-bandsEnergy()-1,8" by adding a and b.
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import warnings
from datetime import datetime
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers.core import Dense, Dropout
#from hyperopt import Trials, STATUS_OK, tpe
#from hyperas import optim
#from hyperas.distributions import choice, uniform
warnings.simplefilter("ignore")

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# get the features from the file features.txt
features = list()
#features = features.drop_duplicates(subset=None, keep=’first’, inplace=False)
with open('UCI_HAR_Dataset/features.txt') as f:
    features = [line.split()[1] for line in f.readlines()]
print('No of Features: {}'.format(len(features)))
# Out:
# No of Features: 561

# %% [markdown]
# # Obtain the train data

# %%
# get the data from txt files to pandas dataffame
X_train = pd.read_csv('UCI_HAR_Dataset/train/X_train.txt', delim_whitespace=True, header=None, names=features)

# add subject column to the dataframe
X_train['subject'] = pd.read_csv('UCI_HAR_Dataset/train/subject_train.txt', header=None, squeeze=True)

y_train = pd.read_csv('UCI_HAR_Dataset/train/y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})

# put all columns in a single dataframe
train = X_train
train['Activity'] = y_train
train['ActivityName'] = y_train_labels
train.sample()
# Out:
#      tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 329           0.329553           -0.04581          -0.068693
#
#      tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 329         -0.346164         -0.088366           0.06106          -0.39366
#
#      tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 329         -0.103891          0.143619         -0.133527  ...
#
#      angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 329                    -0.421951                              0.387345
#
#      angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 329                          0.969871                             -0.619909
#
#      angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 329             -0.611474              0.355605              0.093259
#
#      subject  Activity      ActivityName
# 329        1         2  WALKING_UPSTAIRS
#
# [1 rows x 564 columns]

# %% [markdown]
# ## Obtain the  test data

# %%
# get the data from txt files to pandas dataffame
X_test = pd.read_csv('UCI_HAR_Dataset/test/X_test.txt', delim_whitespace=True, header=None, names=features)

# add subject column to the dataframe
X_test['subject'] = pd.read_csv('UCI_HAR_Dataset/test/subject_test.txt', header=None, squeeze=True)

# get y labels from the txt file
y_test = pd.read_csv('UCI_HAR_Dataset/test/y_test.txt', names=['Activity'], squeeze=True)
y_test_labels = y_test.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})


# put all columns in a single dataframe
test = X_test
test['Activity'] = y_test
test['ActivityName'] = y_test_labels
test.sample()
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 1810            0.19716          -0.019162          -0.026839
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 1810          0.171538          0.006649         -0.300847          0.100904
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 1810         -0.072392         -0.319859          0.374533  ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 1810                      0.33279                             -0.431878
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 1810                         -0.929763                              0.062148
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 1810             -0.828546              0.215091             -0.002222
#
#       subject  Activity        ActivityName
# 1810       13         3  WALKING_DOWNSTAIRS
#
# [1 rows x 564 columns]

# %%
test.shape
# Out:
# (2947, 564)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## 1. Check for Duplicates

# %%
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# No of duplicates in train: 0
# No of duplicates in test : 0

# %% [markdown]
# ## 2. Checking for NaN/null values

# %%
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %% [markdown]
# ## 3. Check for data imbalance

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'

# %%
plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.show()

# %% [markdown]
# > We have got almost same number of reading from all the subjects

# %%
plt.title('No of Datapoints per Activity', fontsize=15)
sns.countplot(train.ActivityName)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Observation
# > Our data is well balanced (almost)

# %% [markdown]
# ## 4. Changing feature names

# %%
columns = train.columns

# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

test.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %% [markdown]
# ## 5. Save this dataframe in a csv files

# %%
train.to_csv('UCI_HAR_Dataset/csv_files/train.csv', index=False)
test.to_csv('UCI_HAR_Dataset/csv_files/test.csv', index=False)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# "___Without domain knowledge EDA has no meaning, without EDA a problem has no soul.___"

# %% [markdown]
# ### 1. Featuring Engineering from Domain Knowledge

# %% [markdown]
# + __Static and Dynamic Activities__
#
#     - In static activities (sit, stand, lie down) motion information will not be very useful.
# 	- In the dynamic activities (Walking, WalkingUpstairs,WalkingDownstairs) motion info will be significant.

# %% [markdown]
# ### 2. Stationary and Moving activities are completely different

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='ActivityName', size=6,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.956,17), xytext=(-0.9, 23), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]

plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.title('Stationary Activities(Zoomed in)')
sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.01, -0.5, 0, 35])
plt.legend(loc='center')

plt.subplot(2,2,2)
plt.title('Moving Activities')
sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Magnitude of an acceleration can saperate it well

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='ActivityName', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# __ Observations__:
# - If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
# - If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# - If tAccMean > 0.0 then the Activity is WalkingDownstairs.
# - We can classify 75% the Acitivity labels with some errors.

# %% [markdown]
# ### 4. Position of GravityAccelerationComponants also matters

# %%
sns.boxplot(x='ActivityName', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# __ Observations__:
# * If angleX,gravityMean > 0 then Activity is Laying.
# * We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %%
sns.boxplot(x='ActivityName', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# # Apply t-sne on the data

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.742s...
# [t-SNE] Computed neighbors for 7352 samples in 25.596s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.635854
# [t-SNE] Computed conditional probabilities in 0.023s
# [t-SNE] Iteration 50: error = 124.7388153, gradient norm = 0.0268353 (50 iterations in 0.738s)
# [t-SNE] Iteration 100: error = 107.3399582, gradient norm = 0.0276561 (50 iterations in 0.673s)
# [t-SNE] Iteration 150: error = 100.9612503, gradient norm = 0.0181999 (50 iterations in 0.599s)
# [t-SNE] Iteration 200: error = 97.5340271, gradient norm = 0.0165129 (50 iterations in 0.677s)
# [t-SNE] Iteration 250: error = 95.2139740, gradient norm = 0.0140064 (50 iterations in 0.676s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 95.213974
# [t-SNE] Iteration 300: error = 4.1221151, gradient norm = 0.0015640 (50 iterations in 0.661s)
# [t-SNE] Iteration 350: error = 3.2119007, gradient norm = 0.0010008 (50 iterations in 0.680s)
# [t-SNE] Iteration 400: error = 2.7816811, gradient norm = 0.0007150 (50 iterations in 0.694s)
# [t-SNE] Iteration 450: error = 2.5181894, gradient norm = 0.0005678 (50 iterations in 0.685s)
# [t-SNE] Iteration 500: error = 2.3347225, gradient norm = 0.0004808 (50 iterations in 0.659s)
# [t-SNE] Iteration 550: error = 2.1970241, gradient norm = 0.0004161 (50 iterations in 0.679s)
# [t-SNE] Iteration 600: error = 2.0879290, gradient norm = 0.0003636 (50 iterations in 0.654s)
# [t-SNE] Iteration 650: error = 1.9981446, gradient norm = 0.0003287 (50 iterations in 0.653s)
# [t-SNE] Iteration 700: error = 1.9225496, gradient norm = 0.0003017 (50 iterations in 0.689s)
# [t-SNE] Iteration 750: error = 1.8577092, gradient norm = 0.0002774 (50 iterations in 0.658s)
# [t-SNE] Iteration 800: error = 1.8014061, gradient norm = 0.0002583 (50 iterations in 0.666s)
# [t-SNE] Iteration 850: error = 1.7513089, gradient norm = 0.0002418 (50 iterations in 0.667s)
# [t-SNE] Iteration 900: error = 1.7067600, gradient norm = 0.0002253 (50 iterations in 0.648s)
# [t-SNE] Iteration 950: error = 1.6667882, gradient norm = 0.0002118 (50 iterations in 0.660s)
# [t-SNE] Iteration 1000: error = 1.6305218, gradient norm = 0.0001979 (50 iterations in 0.729s)
# [t-SNE] KL divergence after 1000 iterations: 1.630522
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.759s...
# [t-SNE] Computed neighbors for 7352 samples in 26.016s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961265
# [t-SNE] Computed conditional probabilities in 0.031s
# [t-SNE] Iteration 50: error = 114.0669708, gradient norm = 0.0198906 (50 iterations in 1.556s)
# [t-SNE] Iteration 100: error = 97.5553665, gradient norm = 0.0169709 (50 iterations in 0.680s)
# [t-SNE] Iteration 150: error = 93.3096924, gradient norm = 0.0082154 (50 iterations in 0.643s)
# [t-SNE] Iteration 200: error = 91.3627930, gradient norm = 0.0062192 (50 iterations in 0.613s)
# [t-SNE] Iteration 250: error = 90.1866837, gradient norm = 0.0050374 (50 iterations in 0.631s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 90.186684
# [t-SNE] Iteration 300: error = 3.5718360, gradient norm = 0.0014535 (50 iterations in 0.604s)
# [t-SNE] Iteration 350: error = 2.8164279, gradient norm = 0.0007467 (50 iterations in 0.611s)
# [t-SNE] Iteration 400: error = 2.4367726, gradient norm = 0.0005225 (50 iterations in 0.609s)
# [t-SNE] Iteration 450: error = 2.2200644, gradient norm = 0.0004054 (50 iterations in 0.630s)
# [t-SNE] Iteration 500: error = 2.0752807, gradient norm = 0.0003326 (50 iterations in 0.637s)
# [t-SNE] Iteration 550: error = 1.9702264, gradient norm = 0.0002845 (50 iterations in 0.642s)
# [t-SNE] Iteration 600: error = 1.8892813, gradient norm = 0.0002476 (50 iterations in 0.652s)
# [t-SNE] Iteration 650: error = 1.8242029, gradient norm = 0.0002185 (50 iterations in 0.645s)
# [t-SNE] Iteration 700: error = 1.7705096, gradient norm = 0.0001979 (50 iterations in 0.642s)
# [t-SNE] Iteration 750: error = 1.7251296, gradient norm = 0.0001818 (50 iterations in 0.649s)
# [t-SNE] Iteration 800: error = 1.6860596, gradient norm = 0.0001652 (50 iterations in 0.641s)
# [t-SNE] Iteration 850: error = 1.6522363, gradient norm = 0.0001520 (50 iterations in 0.650s)
# [t-SNE] Iteration 900: error = 1.6224589, gradient norm = 0.0001426 (50 iterations in 0.655s)
# [t-SNE] Iteration 950: error = 1.5959656, gradient norm = 0.0001342 (50 iterations in 0.645s)
# [t-SNE] Iteration 1000: error = 1.5722263, gradient norm = 0.0001262 (50 iterations in 0.643s)
# [t-SNE] KL divergence after 1000 iterations: 1.572226
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.735s...
# [t-SNE] Computed neighbors for 7352 samples in 26.281s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133828
# [t-SNE] Computed conditional probabilities in 0.063s
# [t-SNE] Iteration 50: error = 106.0343552, gradient norm = 0.0172191 (50 iterations in 0.868s)
# [t-SNE] Iteration 100: error = 91.2167969, gradient norm = 0.0114561 (50 iterations in 0.724s)
# [t-SNE] Iteration 150: error = 87.5759964, gradient norm = 0.0061589 (50 iterations in 0.696s)
# [t-SNE] Iteration 200: error = 86.1609192, gradient norm = 0.0039683 (50 iterations in 0.696s)
# [t-SNE] Iteration 250: error = 85.3901978, gradient norm = 0.0036323 (50 iterations in 0.691s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.390198
# [t-SNE] Iteration 300: error = 3.1278794, gradient norm = 0.0013770 (50 iterations in 0.669s)
# [t-SNE] Iteration 350: error = 2.4893367, gradient norm = 0.0006446 (50 iterations in 0.660s)
# [t-SNE] Iteration 400: error = 2.1706138, gradient norm = 0.0004215 (50 iterations in 0.665s)
# [t-SNE] Iteration 450: error = 1.9866002, gradient norm = 0.0003124 (50 iterations in 0.680s)
# [t-SNE] Iteration 500: error = 1.8686984, gradient norm = 0.0002503 (50 iterations in 0.690s)
# [t-SNE] Iteration 550: error = 1.7851938, gradient norm = 0.0002104 (50 iterations in 0.693s)
# [t-SNE] Iteration 600: error = 1.7225301, gradient norm = 0.0001809 (50 iterations in 0.705s)
# [t-SNE] Iteration 650: error = 1.6738596, gradient norm = 0.0001591 (50 iterations in 0.689s)
# [t-SNE] Iteration 700: error = 1.6343632, gradient norm = 0.0001445 (50 iterations in 0.702s)
# [t-SNE] Iteration 750: error = 1.6017834, gradient norm = 0.0001310 (50 iterations in 0.698s)
# [t-SNE] Iteration 800: error = 1.5744539, gradient norm = 0.0001238 (50 iterations in 0.706s)
# [t-SNE] Iteration 850: error = 1.5515743, gradient norm = 0.0001104 (50 iterations in 0.702s)
# [t-SNE] Iteration 900: error = 1.5317017, gradient norm = 0.0001044 (50 iterations in 0.703s)
# [t-SNE] Iteration 950: error = 1.5141624, gradient norm = 0.0000995 (50 iterations in 0.707s)
# [t-SNE] Iteration 1000: error = 1.4989926, gradient norm = 0.0000937 (50 iterations in 0.704s)
# [t-SNE] KL divergence after 1000 iterations: 1.498993
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.733s...
# [t-SNE] Computed neighbors for 7352 samples in 26.995s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274335
# [t-SNE] Computed conditional probabilities in 0.128s
# [t-SNE] Iteration 50: error = 96.9224472, gradient norm = 0.0262286 (50 iterations in 0.859s)
# [t-SNE] Iteration 100: error = 83.9009705, gradient norm = 0.0068655 (50 iterations in 0.793s)
# [t-SNE] Iteration 150: error = 81.8510971, gradient norm = 0.0034927 (50 iterations in 0.791s)
# [t-SNE] Iteration 200: error = 81.1375732, gradient norm = 0.0024675 (50 iterations in 0.802s)
# [t-SNE] Iteration 250: error = 80.7555389, gradient norm = 0.0021614 (50 iterations in 0.794s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.755539
# [t-SNE] Iteration 300: error = 2.6992097, gradient norm = 0.0013092 (50 iterations in 0.775s)
# [t-SNE] Iteration 350: error = 2.1649694, gradient norm = 0.0005751 (50 iterations in 0.774s)
# [t-SNE] Iteration 400: error = 1.9151971, gradient norm = 0.0003506 (50 iterations in 0.813s)
# [t-SNE] Iteration 450: error = 1.7688589, gradient norm = 0.0002480 (50 iterations in 0.804s)
# [t-SNE] Iteration 500: error = 1.6751398, gradient norm = 0.0001937 (50 iterations in 0.809s)
# [t-SNE] Iteration 550: error = 1.6107240, gradient norm = 0.0001576 (50 iterations in 0.864s)
# [t-SNE] Iteration 600: error = 1.5640838, gradient norm = 0.0001336 (50 iterations in 0.901s)
# [t-SNE] Iteration 650: error = 1.5285144, gradient norm = 0.0001189 (50 iterations in 0.901s)
# [t-SNE] Iteration 700: error = 1.5012779, gradient norm = 0.0001052 (50 iterations in 0.840s)
# [t-SNE] Iteration 750: error = 1.4797592, gradient norm = 0.0000968 (50 iterations in 0.808s)
# [t-SNE] Iteration 800: error = 1.4623933, gradient norm = 0.0000910 (50 iterations in 0.902s)
# [t-SNE] Iteration 850: error = 1.4481184, gradient norm = 0.0000834 (50 iterations in 0.942s)
# [t-SNE] Iteration 900: error = 1.4359388, gradient norm = 0.0000794 (50 iterations in 0.941s)
# [t-SNE] Iteration 950: error = 1.4254713, gradient norm = 0.0000760 (50 iterations in 0.976s)
# [t-SNE] Iteration 1000: error = 1.4168043, gradient norm = 0.0000753 (50 iterations in 0.952s)
# [t-SNE] KL divergence after 1000 iterations: 1.416804
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.731s...
# [t-SNE] Computed neighbors for 7352 samples in 27.858s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.297s
# [t-SNE] Iteration 50: error = 86.7147522, gradient norm = 0.0197997 (50 iterations in 1.229s)
# [t-SNE] Iteration 100: error = 76.0029907, gradient norm = 0.0045302 (50 iterations in 1.240s)
# [t-SNE] Iteration 150: error = 74.9404602, gradient norm = 0.0029738 (50 iterations in 1.213s)
# [t-SNE] Iteration 200: error = 74.4791107, gradient norm = 0.0016945 (50 iterations in 1.199s)
# [t-SNE] Iteration 250: error = 74.2503281, gradient norm = 0.0013004 (50 iterations in 1.202s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.250328
# [t-SNE] Iteration 300: error = 2.1735778, gradient norm = 0.0012053 (50 iterations in 1.163s)
# [t-SNE] Iteration 350: error = 1.7688477, gradient norm = 0.0004897 (50 iterations in 1.162s)
# [t-SNE] Iteration 400: error = 1.5976053, gradient norm = 0.0002836 (50 iterations in 1.163s)
# [t-SNE] Iteration 450: error = 1.5021436, gradient norm = 0.0001928 (50 iterations in 1.155s)
# [t-SNE] Iteration 500: error = 1.4408890, gradient norm = 0.0001470 (50 iterations in 1.146s)
# [t-SNE] Iteration 550: error = 1.3986397, gradient norm = 0.0001178 (50 iterations in 1.186s)
# [t-SNE] Iteration 600: error = 1.3690860, gradient norm = 0.0000968 (50 iterations in 1.204s)
# [t-SNE] Iteration 650: error = 1.3471295, gradient norm = 0.0000845 (50 iterations in 1.233s)
# [t-SNE] Iteration 700: error = 1.3309335, gradient norm = 0.0000742 (50 iterations in 1.259s)
# [t-SNE] Iteration 750: error = 1.3182441, gradient norm = 0.0000681 (50 iterations in 1.262s)
# [t-SNE] Iteration 800: error = 1.3083798, gradient norm = 0.0000639 (50 iterations in 1.258s)
# [t-SNE] Iteration 850: error = 1.3009241, gradient norm = 0.0000597 (50 iterations in 1.274s)
# [t-SNE] Iteration 900: error = 1.2946963, gradient norm = 0.0000558 (50 iterations in 1.267s)
# [t-SNE] Iteration 950: error = 1.2896013, gradient norm = 0.0000549 (50 iterations in 1.293s)
# [t-SNE] Iteration 1000: error = 1.2854548, gradient norm = 0.0000522 (50 iterations in 1.284s)
# [t-SNE] KL divergence after 1000 iterations: 1.285455
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
