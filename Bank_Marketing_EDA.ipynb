# %% [markdown]
# # Exploratory Data Analysis of Bank Marketing project (Data Glacier Internship)

# %% [markdown]
# **Exploratory Data Analysis refers to the critical process of performing initial investigations on data so as to discover patterns,to spot anomalies,to test hypothesis and to check assumptions with the help of summary statistics and graphical representations.**

# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# # Read the file

# %%
bank_df = pd.read_csv('https://raw.githubusercontent.com/amirshq/week-7---Bank-Marketing-Campaign-/main/bank/bank-full%20copy.csv')
bank_df.head(20)
# Out:
#     age           job   marital  education default  balance housing loan  \
# 0    58    management   married   tertiary      no     2143     yes   no
# 1    44    technician    single  secondary      no       29     yes   no
# 2    33  entrepreneur   married  secondary      no        2     yes  yes
# 3    47   blue-collar   married    unknown      no     1506     yes   no
# 4    33       unknown    single    unknown      no        1      no   no
# 5    35    management   married   tertiary      no      231     yes   no
# 6    28    management    single   tertiary      no      447     yes  yes
# 7    42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 8    58       retired   married    primary      no      121     yes   no
# 9    43    technician    single  secondary      no      593     yes   no
# 10   41        admin.  divorced  secondary      no      270     yes   no
# 11   29        admin.    single  secondary      no      390     yes   no
# ...

# %%
bank_df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
bank_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
bank_df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
bank_df['default'] = bank_df['default'].map({'yes':1 , 'no':0})
bank_df['housing'] = bank_df['housing'].map({'yes':1 , 'no':0})
bank_df['loan'] = bank_df['loan'].map({'yes':1 , 'no':0})
bank_df['y'] = bank_df['y'].map({'yes':1 , 'no':0})

# %%
bank_df
# Out:
#        age           job   marital  education  default  balance  housing  \
# 0       58    management   married   tertiary        0     2143        1
# 1       44    technician    single  secondary        0       29        1
# 2       33  entrepreneur   married  secondary        0        2        1
# 3       47   blue-collar   married    unknown        0     1506        1
# 4       33       unknown    single    unknown        0        1        0
# ...    ...           ...       ...        ...      ...      ...      ...
# 45206   51    technician   married   tertiary        0      825        0
# 45207   71       retired  divorced    primary        0     1729        0
# 45208   72       retired   married  secondary        0     5715        0
# 45209   57   blue-collar   married  secondary        0      668        0
# 45210   37  entrepreneur   married  secondary        0     2971        0
#
#        loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
bank_df.drop(bank_df[bank_df['job'] == 'unknown'].index , inplace = True)
bank_df.drop(bank_df[bank_df['marital'] == 'unknown'].index , inplace = True)
bank_df.drop(bank_df[bank_df['education'] == 'unknown'].index , inplace = True)
bank_df.drop(bank_df[bank_df['default'] == 'unknown'].index , inplace = True)
bank_df.drop(bank_df[bank_df['housing'] == 'unknown'].index , inplace = True)
bank_df.drop(bank_df[bank_df['loan'] == 'unknown'].index , inplace = True)

# %%
bank_df
# Out:
#        age           job   marital  education  default  balance  housing  \
# 0       58    management   married   tertiary        0     2143        1
# 1       44    technician    single  secondary        0       29        1
# 2       33  entrepreneur   married  secondary        0        2        1
# 5       35    management   married   tertiary        0      231        1
# 6       28    management    single   tertiary        0      447        1
# ...    ...           ...       ...        ...      ...      ...      ...
# 45206   51    technician   married   tertiary        0      825        0
# 45207   71       retired  divorced    primary        0     1729        0
# 45208   72       retired   married  secondary        0     5715        0
# 45209   57   blue-collar   married  secondary        0      668        0
# 45210   37  entrepreneur   married  secondary        0     2971        0
#
#        loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
bank_df.describe()
# Out:
#                 age       default        balance       housing          loan  \
# count  43193.000000  43193.000000   43193.000000  43193.000000  43193.000000
# mean      40.764082      0.018105    1354.027342      0.562406      0.164541
# std       10.512640      0.133332    3042.103625      0.496096      0.370770
# min       18.000000      0.000000   -8019.000000      0.000000      0.000000
# 25%       33.000000      0.000000      71.000000      0.000000      0.000000
# 50%       39.000000      0.000000     442.000000      1.000000      0.000000
# 75%       48.000000      0.000000    1412.000000      1.000000      0.000000
# max       95.000000      1.000000  102127.000000      1.000000      1.000000
#
#                 day      duration      campaign         pdays      previous  \
# count  43193.000000  43193.000000  43193.000000  43193.000000  43193.000000
# mean      15.809414    258.323409      2.758178     40.404070      0.584863
# ...

# %%
bank_df.value_counts(['y'])
# Out:
# y
# 0    38172
# 1     5021
# dtype: int64

# %%
sns.countplot( x='y' , data = bank_df )

# %%
cnoloan = len(bank_df[bank_df['y']== 0])
cyesloan= len(bank_df[bank_df['y']== 1])


print(f'The percentage of customers who not get the loan = {cnoloan/len(bank_df.y)*100:.2f}% ')
print(f'The percentage of customers who get the loan = {cyesloan/len(bank_df.y)*100:.2f}% ')
# Out:
# The percentage of customers who not get the loan = 88.38%
# The percentage of customers who get the loan = 11.62%

# %%
bank_df.groupby('y').mean()
# Out:
#          age   default      balance   housing      loan        day  \
# y
# 0  40.669679  0.019229  1297.333176  0.587289  0.173792  15.900529
# 1  41.481777  0.009560  1785.043019  0.373232  0.094204  15.116710
#
#      duration  campaign      pdays  previous
# y
# 0  221.115949  2.838704  36.709394  0.507230
# 1  541.191994  2.145987  68.492731  1.175065

# %%
sns.countplot(x = 'y', hue = 'job', data = bank_df)

# %%
sns.countplot(x='y' , hue = 'marital', data = bank_df)

# %%
bank_df['education'].value_counts()
# Out:
# secondary    23131
# tertiary     13262
# primary       6800
# Name: education, dtype: int64

# %%
sns.countplot(x = 'y', hue = 'education' , data = bank_df)

# %%
sns.countplot(x="y",hue = "month", data=bank_df)

# %%
sns.distplot(bank_df.age)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(bank_df.age.values)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.distplot(bank_df.balance)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(bank_df.balance)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.histplot(bank_df.duration)

# %%
sns.boxplot(bank_df.duration)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.displot(bank_df.pdays)

# %%
sns.boxplot(bank_df.pdays.values, color = 'b')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.displot(bank_df.campaign)

# %%
sns.boxplot(bank_df.campaign.values, color = 'y')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Compute Skewness

# %% [markdown]
# **skewness refers to a distortion or asymmetry that deviates from the symmetrical bell curve, or normal distribution, in a set of data**

# %% [markdown]
# In statistics, skewness is a measure of the asymmetry of the probability distribution of a random variable about its mean. In other words, skewness tells you the amount and direction of skew (departure from horizontal symmetry). The skewness value can be positive or negative, or even undefined. If skewness is 0, the data are perfectly symmetrical, although it is quite unlikely for real-world data. As a general rule of thumb:
#
# * If skewness is less than -1 or greater than 1, the distribution is highly skewed.
# * If skewness is between -1 and -0.5 or between 0.5 and 1, the distribution is moderately skewed.
# * If skewness is between -0.5 and 0.5, the distribution is approximately symmetric.

# %% [markdown]
# ![b259c8b7-0202-49c1-b0a6-3927209575a7.png](data:image/png;base64,...)

# %%
cols=["age","duration","campaign","pdays","previous","balance"]
for item in cols:
  print(f'Skewness {item}: {str(bank_df[item].skew())}')
# Out:
# Skewness age: 0.6978356364509636
# Skewness duration: 3.1701799697784785
# Skewness campaign: 4.7924941810208885
# Skewness pdays: 2.608337543002269
# Skewness previous: 42.08877792244101
# Skewness balance: 8.400120937754398

# %%
plotter = bank_df.groupby(["day","y"]).y.count()
plt.figure(figsize=(14,6))

#unstack = Returns a DataFrame having a new level of column labels whose inner-most level consists of the pivoted index labels.
plotter.unstack().plot(kind="bar")
plt.ylabel("No.of Customers")
plt.title("Term deposit subscribed based on pdays")
# Out:
# Text(0.5, 1.0, 'Term deposit subscribed based on pdays')

# %%
plotter = bank_df.groupby(["education", "y"]).y.count()
plt.figure(figsize=(14,6))
plotter.unstack().plot(kind="bar")
plt.ylabel("No.of Customers")
plt.title("Term Deposit subscribed based on Education")
# Out:
# Text(0.5, 1.0, 'Term Deposit subscribed based on Education')

# %% [markdown]
# **The difference between the next 2 plot is Important (One of the plots is in Percentage)**

# %%
from matplotlib.pyplot import figure
from matplotlib import pyplot as plt
figure(figsize=(6,6))
total = len(bank_df['y'])
plot = sns.countplot(x=bank_df['y'], data = bank_df)

# %%
from matplotlib.pyplot import figure
from matplotlib import pyplot as plt
figure(figsize=(6,6))
total = len(bank_df['y'])
plot = sns.countplot(x=bank_df['y'], data = bank_df)
#plot.patches gives x,y coordinate,height width and angle and using this i have converted the labels into the perctage
#to make it interpretable.
for p in plot.patches:
    plot.annotate('{:.1f}%'.format(100*p.get_height()/total), (p.get_x(), p.get_height()))
plot.yaxis.set_ticks(np.linspace(0, total, 11))
plot.set_yticklabels(map('{:.1f}%'.format, 100*plot.yaxis.get_majorticklocs()/total))
plt.show()

# %% [markdown]
# ## Bar Chart by Term Deposit

# %%
plot2 =bank_df.groupby(["education","y"]).y.count()
plt.figure(figsize=(100,50))
plot2.unstack().plot(kind="bar" ,stacked=True)
plt.title("Term deposit subscribed based on education")
# Out:
# Text(0.5, 1.0, 'Term deposit subscribed based on education')

# %%
plot2 =bank_df.groupby(["housing","y"]).y.count()
plt.figure(figsize=(100,50))
plot2.unstack().plot(kind="bar" ,stacked=True)
plt.title("Term deposit subscribed based on housing")
# Out:
# Text(0.5, 1.0, 'Term deposit subscribed based on housing')

# %%
plot2 =bank_df.groupby(["marital","y"]).y.count()
plt.figure(figsize=(100,50))
plot2.unstack().plot(kind="bar" ,stacked=True)
plt.title("Term deposit subscribed based on marital")
# Out:
# Text(0.5, 1.0, 'Term deposit subscribed based on marital')

# %%
plot2 =bank_df.groupby(["job","y"]).y.count()
plt.figure(figsize=(100,50))
plot2.unstack().plot(kind="bar" ,stacked=True)
plt.title("Term deposit subscribed based on job")
# Out:
# Text(0.5, 1.0, 'Term deposit subscribed based on job')

# %%
plot2 =bank_df.groupby(["month","y"]).y.count()
plt.figure(figsize=(100,50))
plot2.unstack().plot(kind="bar" ,stacked=True)
plt.title("Term deposit subscribed based on month")
# Out:
# Text(0.5, 1.0, 'Term deposit subscribed based on month')

# %%
plot2 =bank_df.groupby(["contact","y"]).y.count()
plt.figure(figsize=(100,50))
plot2.unstack().plot(kind="bar" ,stacked=True)
plt.title("Term deposit subscribed based on contact")
# Out:
# Text(0.5, 1.0, 'Term deposit subscribed based on contact')

# %%
plot2 = bank_df.groupby(["poutcome","y"]).y.count()
plt.figure(figsize = (100, 50))
plot2.unstack().plot(kind= "bar", stacked = True)
plt.title("Term deposit subscribed based on poutcome")
# Out:
# Text(0.5, 1.0, 'Term deposit subscribed based on poutcome')

# %%
plot2 = bank_df.groupby(["loan", "y"]).y.count()
plt.figure(figsize = (100,50))
plot2.unstack().plot(kind="bar", stacked = True)
plt.title("Term deposit subscribed based on Loan")
# Out:
# Text(0.5, 1.0, 'Term deposit subscribed based on Loan')

# %%
plot2 =bank_df.groupby(["campaign","y"]).y.count()
plt.figure(figsize=(50,25))
plot2.unstack().plot(kind="bar" ,stacked=True)
plt.title("Term deposit subscribed based on campaign")
# Out:
# Text(0.5, 1.0, 'Term deposit subscribed based on campaign')

# %% [markdown]
# ## Plot Bar chart by age group

# %%
import pandas as pd
data1 = bank_df[(bank_df['age']>18) & (bank_df['age']<=25)].groupby(['loan'])['y'].count()
data2 = bank_df[(bank_df['age']>26) & (bank_df['age']<=40)].groupby(['loan'])['y'].count()
data3 = bank_df[(bank_df['age']>41) & (bank_df['age']<=60)].groupby(['loan'])['y'].count()
data4 = bank_df[(bank_df['age']>60)].groupby(['loan'])['y'].count()

df=pd.DataFrame({'60+':data4,'41-60':data3,'26-40':data2,'18-25':data1 })
ax = df.plot(kind='bar', stacked=True, width = 0.55)

plt.title("Profit share by age group")
plt.ylabel(' Profit')
plt.show()

# %% [markdown]
# **Important Difference**
#
# df.plot(kind = 'bar')
#
# ![download.png](data:image/png;base64,...)
# Vs
#
# df.plot(kind = 'bar', stacked = True)
#
# ![download (1).png](data:image/png;base64,...)

# %%
data1 = bank_df[(bank_df['age']>18) & (bank_df['age']<=25)].groupby(['housing' , 'loan'])['y'].count()
data2 = bank_df[(bank_df['age']>26) & (bank_df['age']<=40)].groupby(['housing' , 'loan'])['y'].count()
data3 = bank_df[(bank_df['age']>41) & (bank_df['age']<=60)].groupby(['housing' , 'loan'])['y'].count()
data4 = bank_df[(bank_df['age']>60)].groupby(['housing' , 'loan'])['y'].count()

df = pd.DataFrame({'60+':data4, '41-60':data3 , '26-40':data2 , '18-25':data1})
ax = df.plot(kind="bar", stacked = True , width=0.55)

plt.title('Profit share by age group')
plt.ylabel("profit")
plt.show()

# %%
data1 = bank_df[(bank_df['age']>18) & (bank_df['age']<=25)].groupby(['education' , 'loan'])['y'].count()
data2 = bank_df[(bank_df['age']>26) & (bank_df['age']<=40)].groupby(['education' , 'loan'])['y'].count()
data3 = bank_df[(bank_df['age']>41) & (bank_df['age']<=60)].groupby(['education' , 'loan'])['y'].count()
data4 = bank_df[(bank_df['age']>60)].groupby(['education' , 'loan'])['y'].count()

df = pd.DataFrame({'60+':data4, '41-60':data3 , '26-40':data2 , '18-25':data1})
ax = df.plot(kind="bar", stacked = True , width=0.55)

plt.title('Profit share by age group')
plt.ylabel("profit")
plt.show()

# %%
data1 = bank_df[(bank_df['age']>18) & (bank_df['age']<=25)].groupby(['education'])['y'].count()
data2 = bank_df[(bank_df['age']>26) & (bank_df['age']<=40)].groupby(['education'])['y'].count()
data3 = bank_df[(bank_df['age']>41) & (bank_df['age']<=60)].groupby(['education'])['y'].count()
data4 = bank_df[(bank_df['age']>60)].groupby(['education'])['y'].count()

df = pd.DataFrame({'60+':data4, '41-60':data3 , '26-40':data2 , '18-25':data1})
ax = df.plot(kind="bar", stacked = True , width=0.55)

plt.title('Profit share by age group')
plt.ylabel("profit")
plt.show()

# %% [markdown]
# ## Create 75th percentile of Data

# %%
#function to find the 75th percentile
def func75(x):
  return np.quantile(x,0.75)

# %%
bank_df.groupby('y')['balance'].aggregate(['mean','median',func75]).plot.bar()
plt.title('term deposit estimation according to balance parameters')
plt.show()

# %%
bank_df.groupby('y')['duration'].aggregate(['mean','median',func75]).plot.bar()
plt.title("term deposit estimation according to duration parameters")
plt.show()

# %% [markdown]
# # Create Pivot Tables and Plot Heatmaps

# %% [markdown]
# ## Create Pivot Table for education and marital status

# %%
res = pd.pivot_table(data = bank_df, index = 'education', columns= 'marital', values='y')
print(res)
# Out:
# marital    divorced   married    single
# education
# primary    0.139037  0.075475  0.107692
# secondary  0.103485  0.094565  0.129228
# tertiary   0.138283  0.130044  0.183434

# %% [markdown]
# ## Plot Heatmap for education and marital status

# %%
sns.heatmap(res, annot = True)
plt.show()

# %%
sns.heatmap(res, annot = True, cmap = 'YlGn')
sns.set(rc = {'figure.figsize':(20,10)})      
plt.show()

# %% [markdown]
# ## Create Pivot Table for education and marital status

# %%
res = pd.pivot_table(data= bank_df, index = 'job', columns = 'marital', values='y')
print(res)
# Out:
# marital        divorced   married    single
# job
# admin.         0.121585  0.113302  0.137337
# blue-collar    0.077356  0.062237  0.107572
# entrepreneur   0.075145  0.077075  0.110619
# housemaid      0.101124  0.071672  0.173913
# management     0.125000  0.123115  0.163272
# retired        0.288835  0.217178  0.126214
# self-employed  0.158273  0.077320  0.197216
# services       0.089015  0.073498  0.114359
# student        0.200000  0.181818  0.298898
# technician     0.081111  0.104455  0.131816
# unemployed     0.152941  0.132867  0.197943

# %% [markdown]
# ## Plot Heatmap for education and marital status

# %%
sns.heatmap(res, annot= True, cmap = 'YlGn')
sns.set(rc = {'figure.figsize':(20,10)})
plt.show()

# %% [markdown]
# ## Create Pivot Table for education and Poutcome status

# %%
res = pd.pivot_table(data = bank_df, index='education', columns= 'poutcome', values='y')
print(res)
# Out:
# poutcome    failure     other   success   unknown
# education
# primary    0.088924  0.143443  0.606061  0.071935
# secondary  0.108140  0.139959  0.639881  0.084370
# tertiary   0.168683  0.220588  0.656452  0.114420

# %% [markdown]
# ## Plot Heatmap for education and poutcome

# %%
sns.heatmap(res, annot= True, cmap ='YlGn')
sns.set(rc = {'figure.figsize':(20,10)})
plt.show()

# %%
bank_df.head(10)
# Out:
#     age           job   marital  education  default  balance  housing  loan  \
# 0    58    management   married   tertiary        0     2143        1     0
# 1    44    technician    single  secondary        0       29        1     0
# 2    33  entrepreneur   married  secondary        0        2        1     1
# 5    35    management   married   tertiary        0      231        1     0
# 6    28    management    single   tertiary        0      447        1     1
# 7    42  entrepreneur  divorced   tertiary        1        2        1     0
# 8    58       retired   married    primary        0      121        1     0
# 9    43    technician    single  secondary        0      593        1     0
# 10   41        admin.  divorced  secondary        0      270        1     0
# 11   29        admin.    single  secondary        0      390        1     0
#
#     contact  day month  duration  campaign  pdays  previous poutcome  y
# ...

# %% [markdown]
# ## Create Pivot Table for Housing and Loan

# %%
res = pd.pivot_table(data= bank_df, index = 'housing', columns = 'loan', values='y')
print(res)
# Out:
# loan            0         1
# housing
# 0        0.182219  0.076705
# 1        0.080846  0.059893

# %% [markdown]
# ## Plot Heatmap for Housing and Loan

# %%
sns.heatmap(res, annot = True , cmap = 'YlGn')
sns.set(rc = {'figure.figsize':(20,10)})
plt.show()

# %% [markdown]
# ## Create Pivot Table for Housing and marital status

# %%
res= pd.pivot_table(data= bank_df, index='housing', columns = 'marital', values = 'y')
print(res)
# Out:
# marital  divorced   married    single
# housing
# 0        0.159729  0.146735  0.209117
# 1        0.086941  0.065278  0.099238

# %% [markdown]
# ## Plot Heatmap for Housing and marital

# %%
sns.heatmap(res, annot= True, cmap= 'YlGn')
sns.set(rc = {'figure.figsize':(20,10)})
plt.show()

# %% [markdown]
# ## ScatterPlot for The Relationship between the Number and Duration of Calls

# %%
bank_df['duration']= bank_df['duration'].apply(lambda item:item/60).round(2)                    #kind of Normalization for better fit on the plot
duration_campaigne = sns.scatterplot(data = bank_df, x= 'duration', y='campaign', hue='y')

sns.set(rc = {'figure.figsize':(20,10)})                                                        #Increase the size of plot

plt.axis([0,65,0,65])
plt.ylabel('Number of Calls')
plt.xlabel('Duration of Calls (Minutes)')
plt.title('The Relationship between the Number and Duration of Calls')
plt.show()

# %%
bank_df['pdays']
# Out:
# 0         -1
# 1         -1
# 2         -1
# 5         -1
# 6         -1
#         ...
# 45206     -1
# 45207     -1
# 45208    184
# 45209     -1
# 45210    188
# Name: pdays, Length: 43193, dtype: int64

# %%
plt.plot(bank_df['pdays'])

# %% [markdown]
# # Random Sampling

# %% [markdown]
# The Imbalanced classification problem is what we face when there is a severe skew in the class distribution of our training data. Okay, the skew may not be extremely severe (it can vary), but the reason we identify imbalanced classification as a problem is because it can influence the performance on our Machine Learning algorithms.
#
# **One way the imbalance may affect our Machine Learning algorithm is when our algorithm completely ignores the minority class. The reason this is an issue is because the minority class is often the class that we are most interested in.**
#
# ![1_emgamRvmZiswj9AYoycEFQ.png](data:image/png;base64,...)
#
# An approach to combat this challenge is **Random Sampling.** There are two main ways to perform random resampling, both of which have there pros and cons:
#
# **Oversampling — Duplicating samples from the minority class**
#
# **Undersampling — Deleting samples from the majority class**
#
# In other words, Both oversampling and undersampling involve introducing a bias to select more samples from one class than from another, to compensate for an imbalance that is either already present in the data, or likely to develop if a purely random sample were taken

# %%
sns.countplot(x='y', data = bank_df)

lenght1 = len(bank_df[bank_df['y']==0])
lenght2 = len(bank_df[bank_df['y']==1])
lenght3 = len(bank_df['y'])
print(f'The percentage of customers who not have the Loan= {(lenght1/lenght3)*100:.2f}%')
print(f'The percentage of customers who  have the Loan= {(lenght2/lenght3)*100:.2f}%')
# Out:
# The percentage of customers who not have the Loan= 88.38%
# The percentage of customers who  have the Loan= 11.62%

# %% [markdown]
# **As we can see, There are huge difference between y=1 and y=0, So the ML algorithm will omit the smaller value. To overcome this problem, we will use Undersampling**

# %%
len(bank_df[bank_df['y'] == 0])
# Out:
# 38172

# %% [markdown]
# ## UnderSampling

# %%
minority_class_len = len(bank_df[bank_df['y']==0])
majority_class_len = len(bank_df[bank_df['y']==1])
print(f'minority class size= {minority_class_len}')
print(f'majority class size= {majority_class_len}')
# Out:
# minority class size= 38172
# majority class size= 5021

# %%
majority_class_indices = bank_df[bank_df['y']==0].index
print(majority_class_indices)
# Out:
# Int64Index([    0,     1,     2,     5,     6,     7,     8,     9,    10,
#                11,
#             ...
#             45180, 45181, 45183, 45184, 45189, 45194, 45198, 45199, 45209,
#             45210],
#            dtype='int64', length=38172)

# %%
###random_majority_indices = np.random.choice(majority_class_indices,minority_class_len, replace = False)
#print(len(random_majority_indices))


random_majority_indices = np.random.choice(majority_class_indices,
                                           minority_class_len, 
                                           replace=False)
print(len(random_majority_indices))
# Out:
# 38172

# %%
minority_class_indices = bank_df[bank_df['y']==1].index
print(majority_class_indices)
# Out:
# Int64Index([    0,     1,     2,     5,     6,     7,     8,     9,    10,
#                11,
#             ...
#             45180, 45181, 45183, 45184, 45189, 45194, 45198, 45199, 45209,
#             45210],
#            dtype='int64', length=38172)

# %%
under_sample_indices = np.concatenate([minority_class_indices,random_majority_indices])
under_sample = bank_df.loc[under_sample_indices]
sns.countplot(x= 'y', data = under_sample)

# %%
bank_df
# Out:
#        age           job   marital  education  default  balance  housing  \
# 0       58    management   married   tertiary        0     2143        1
# 1       44    technician    single  secondary        0       29        1
# 2       33  entrepreneur   married  secondary        0        2        1
# 5       35    management   married   tertiary        0      231        1
# 6       28    management    single   tertiary        0      447        1
# ...    ...           ...       ...        ...      ...      ...      ...
# 45206   51    technician   married   tertiary        0      825        0
# 45207   71       retired  divorced    primary        0     1729        0
# 45208   72       retired   married  secondary        0     5715        0
# 45209   57   blue-collar   married  secondary        0      668        0
# 45210   37  entrepreneur   married  secondary        0     2971        0
#
#        loan    contact  day month  duration  campaign  pdays  previous  \
# ...

# %%
bank_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43193 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        43193 non-null  int64
#  1   job        43193 non-null  object
#  2   marital    43193 non-null  object
#  3   education  43193 non-null  object
#  4   default    43193 non-null  int64
#  5   balance    43193 non-null  int64
#  6   housing    43193 non-null  int64
#  7   loan       43193 non-null  int64
#  8   contact    43193 non-null  object
#  9   day        43193 non-null  int64
#  10  month      43193 non-null  object
#  11  duration   43193 non-null  float64
#  12  campaign   43193 non-null  int64
#  13  pdays      43193 non-null  int64
#  14  previous   43193 non-null  int64
#  15  poutcome   43193 non-null  object
#  16  y          43193 non-null  int64
# dtypes: float64(1), int64(10), object(6)
# memory usage: 6.9+ MB

# %%
category_cols = list(bank_df.select_dtypes(include=['object']))
print(category_cols)
for col in category_cols:
    plt.figure(figsize=(10,4))
    #Returns counts of unique values for each outcome for each feature.
    pos_counts = bank_df.loc[bank_df.y.values == 1, col].value_counts() 
    neg_counts = bank_df.loc[bank_df.y.values == 0, col].value_counts()
    all_counts = list(set(list(pos_counts.index) + list(neg_counts.index)))
    
    #Counts of how often each outcome was recorded.
    freq_pos = (bank_df.y.values == 1).sum()
    freq_neg = (bank_df.y.values == 0).sum()
    
    pos_counts = pos_counts.to_dict()
    neg_counts = neg_counts.to_dict()
    
    all_index = list(all_counts)
    all_counts = [pos_counts.get(k, 0) / freq_pos - neg_counts.get(k, 0) / freq_neg for k in all_counts]

    sns.barplot(all_counts, all_index)
    plt.title(col)
    plt.tight_layout()
# Out:
# ['job', 'marital', 'education', 'contact', 'month', 'poutcome']
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %% [markdown]
# **Important Difference for the next two charts**

# %%
fig = plt.figure(figsize=(16,8))
plt.title('Number of subscribed clients per Job', fontweight='bold')
ax = sns.countplot(data =bank_df , x='job', hue='y')
plt.show()

# %%
fig = plt.figure(figsize=(16,8))
plt.title('Number of subscribed clients per Job', fontweight='bold')
ax = sns.countplot(data =bank_df , x='job', hue='y')
size = float(bank_df.shape[0])
for p in ax.patches:
        height = p.get_height()
        ax.text(p.get_x()+p.get_width()/2., height + 4, '{:1.2f}%'.format(100 * height/size), ha='center')
plt.grid(False)
plt.legend(loc='best')
plt.show()

# %%
fig = plt.figure(figsize=(16,8))
plt.title('Number of subscribed clients per Job', fontweight='bold')
ax = sns.countplot(data =bank_df , x='education', hue='y')
size = float(bank_df.shape[0])
for p in ax.patches:
        height = p.get_height()
        ax.text(p.get_x()+p.get_width()/2., height + 4, '{:1.2f}%'.format(100 * height/size), ha='center')
plt.grid(False)
plt.legend(loc='best')
plt.show()

# %%
fig = plt.figure(figsize=(16,8))
plt.title('Number of subscribed clients per Job', fontweight='bold')
ax = sns.countplot(data =bank_df , x='marital', hue='y')
size = float(bank_df.shape[0])
for p in ax.patches:
        height = p.get_height()
        ax.text(p.get_x()+p.get_width()/2., height + 4, '{:1.2f}%'.format(100 * height/size), ha='center')
plt.grid(False)
plt.legend(loc='best')
plt.show()

# %%
fig = plt.figure(figsize=(16,8))
plt.title('Number of subscribed clients per Job', fontweight='bold')
ax = sns.countplot(data =bank_df , x='y')
size = float(bank_df.shape[0])
for p in ax.patches:
        height = p.get_height()
        ax.text(p.get_x()+p.get_width()/2., height + 4, '{:1.2f}%'.format(100 * height/size), ha='center')
plt.grid(False)
plt.legend(loc='best')
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
fig = plt.figure(figsize=(16,8))
plt.title('Number of subscribed clients per Job', fontweight='bold')
ax = sns.countplot(data =bank_df , x='poutcome', hue='y')
size = float(bank_df.shape[0])
for p in ax.patches:
        height = p.get_height()
        ax.text(p.get_x()+p.get_width()/2., height + 4, '{:1.2f}%'.format(100 * height/size), ha='center')
plt.grid(False)
plt.legend(loc='best')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.heatmap(bank_df.corr(),linewidths=.1,cmap="YlGnBu", annot=True)
plt.yticks(rotation=0);
plt.suptitle('Correlation Matrix')
# Out:
# Text(0.5, 0.98, 'Correlation Matrix')

# %% [markdown]
# ## Reviwed by Kashish and Mohini

# %% [markdown]
# ### Key Points:

# %% [markdown]
# the columns which has two values('yes' and 'no') and slightly imbalanced such as default, loan, y, has been converted to (1,0) numerical values. rest are continuous variable were binned so that outliers value are converted into count values.

# %% [markdown]
# Amir has decided to drop the outliers and ambiguous values, such as "others" and "unknown".

# %% [markdown]
# Skewness doesn't provieds much insights in data, as values of columns are nearly zero apart from 'previous'. data seems symetrical.

# %% [markdown]
# floring and clapping using interquintile range(IQR) Outlires are removed by dropping values that is below 25% and 75% percentile.

# %% [markdown]
# Amir used undersampling method to delete the samples in majority class  as There are huge difference between y=1 and y=0, So the ML algorithm will omit the smaller value, which may affect the perfornamce of algorithm.

# %% [markdown]
# overall visualization provides beautiful insights and cleaned data.
